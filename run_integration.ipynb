# %%
import scCobra
from scCobra import scCobra, label_transfer
from scCobra.plot import embedding
import scanpy as sc
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns

sc.settings.verbosity = 3             
sc.settings.set_figure_params(dpi=80, facecolor='white',figsize=(3,3),frameon=True)
sc.logging.print_header()
plt.rcParams['axes.unicode_minus']=False

sns.__version__
# Out:
# scanpy==1.9.8 anndata==0.10.5.post1 umap==0.5.5 numpy==1.26.4 scipy==1.11.4 pandas==1.5.3 scikit-learn==1.4.1.post1 statsmodels==0.14.1 igraph==0.11.4 pynndescent==0.5.11
# '0.13.2'

# %%
adata_ref=scCobra('pancreas.h5ad',batch_name='batch',min_features=200, min_cells=3, outdir='pancreas_output/',show=False,gpu=0)
# Out:
# pancreas.h5ad
# 2025-05-07 00:38:47,858 - scCobra - INFO - Raw dataset shape: (16401, 14895)
# 2025-05-07 00:38:47,858 - scCobra - INFO - Raw dataset shape: (16401, 14895)
# 2025-05-07 00:38:47,859 - scCobra - INFO - There are 8 batches under batch_name: batch
# 2025-05-07 00:38:47,859 - scCobra - INFO - There are 8 batches under batch_name: batch
# 2025-05-07 00:38:47,951 - scCobra - INFO - Preprocessing
# 2025-05-07 00:38:47,951 - scCobra - INFO - Preprocessing
# 2025-05-07 00:38:47,953 - scCobra - INFO - Filtering out MT genes
# 2025-05-07 00:38:47,953 - scCobra - INFO - Filtering out MT genes
# 2025-05-07 00:38:47,961 - scCobra - INFO - Filtering cells
# 2025-05-07 00:38:47,961 - scCobra - INFO - Filtering cells
# filtered out 697 cells that have less than 200 genes expressed
# /home/bowen/miniconda3/envs/scCobra/lib/python3.9/site-packages/scanpy/preprocessing/_simple.py:139: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
# ...

# %%
sc.pl.umap(adata_ref,color=['batch', 'celltype'],legend_fontsize=10)
# Out:
# /home/bowen/miniconda3/envs/scCobra/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# /home/bowen/miniconda3/envs/scCobra/lib/python3.9/site-packages/scanpy/plotting/_tools/scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
